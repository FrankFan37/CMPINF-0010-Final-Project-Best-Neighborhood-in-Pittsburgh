# %% [markdown]
# # CMPINF 0010: Best Neighborhood - Pittsburgh Arrests Rate
#
# ## Group member: Hongkun Yao
#
# Safety is the most important consideration of estimating the quality of neighborhoods. Arrests data can prove the crime rate of a neighborhood and help us to determine the best neighborhood in Pittsburgh.
#
# In this notebook, I am using the bar chart to visualize the arrests data in each neighborhood. Because of this datasets presents the arrests data by the number of appearing of each neighborhood. I used the value count method to count number of rows with each unique value of variable.

# %%
import pandas as pd
import matplotlib.pyplot as plt

#import arrest dataset
pittarrest = pd.read_csv("pittarrest.csv", sep=",")
#get the random 10 datas
pittarrest.sample(10)
# Out:
#             PK       CCR   AGE GENDER RACE           ARRESTTIME  \
# 53800  2045378  22016785  42.0      M    B  2022-02-03T01:06:00
# 20988  2001119  18103180  29.0      M    B  2018-05-31T20:30:00
# 23708  2004626  18161728  55.0      M    B  2018-08-21T19:59:00
# 52643  2043784  21214383  62.0      F    W  2021-11-27T20:15:00
# 37414  2022126  19220516  17.0      M    W  2019-12-16T12:10:00
# 53965  2045632  22022307  32.0      M    B  2022-02-13T21:29:00
# 10748  1988051  17133631  36.0      M    B  2017-07-17T14:10:00
# 38426  2023449  20010643  18.0      F    B  2020-01-15T20:09:00
# 19970  1999889  18066819  16.0      M    B  2018-05-04T10:00:00
# 41960  2028664  20122045  25.0      F    W  2020-07-03T20:10:00
#
#                                      ARRESTLOCATION  \
# 53800      700 Block N Lang AV Pittsburgh, PA 15208
# 20988     3100 Block Ladoga ST Pittsburgh, PA 15204
# 23708       6200 Block Penn AV Pittsburgh, PA 15206
# 52643    300 Block Sapphire WY Pittsburgh, PA 15224
# 37414         600 Block 1st AV Pittsburgh, PA 15219
# 53965  8000 Block Moosehart ST Pittsburgh, PA 15221
# 10748   200 Block Arlington AV Pittsburgh, PA 15203
# 38426       6200 Block Penn AV Pittsburgh, PA 15206
# 19970         600 Block 1ST AV PITTSBURGH, PA 15219
# 41960         5th AV & Penn AV Pittsburgh, PA 15208
#
#                                                 OFFENSES  \
# 53800  5503 Disorderly Conduct. / 3503.B1I DEF. TRESP...
# 20988  903 Criminal Conspiracy. / 5121 Escape. / 3323...
# 23708                                 3929 Retail Theft.
# 52643  2701 Simple Assault. / 13(a)(32) Paraphernalia...
# 37414           903 Criminal Conspiracy. / 3701 Robbery.
# 53965                               2701 Simple Assault.
# 10748  903 Criminal Conspiracy. / 2702 Aggravated Ass...
# 38426  5902(a)(1) Prostitution  / 5902(a)(2) Prostitu...
# 19970       13(a)(31) Marijuana: Possession Small Amount
# 41960  13(a)(32) Paraphernalia - Use or Possession / ...
#
#                                       INCIDENTLOCATION INCIDENTNEIGHBORHOOD  \
# 53800         700 Block N Lang AV Pittsburgh, PA 15208       Homewood South
# 20988        3100 Block Ladoga ST Pittsburgh, PA 15204              Windgap
# 23708          6200 Block Penn AV Pittsburgh, PA 15206         East Liberty
# 52643       300 Block Sapphire WY Pittsburgh, PA 15224           Bloomfield
# 37414  Stebbins AV & Brookline BL Pittsburgh, PA 15226            Brookline
# 53965     8000 Block Moosehart ST Pittsburgh, PA 15221           East Hills
# 10748      200 Block Arlington AV Pittsburgh, PA 15203          South Shore
# 38426          6200 Block Penn AV Pittsburgh, PA 15206         East Liberty
# 19970    1100 Block N MURTLAND ST PITTSBURGH, PA 15208        Homewood West
# 41960            5th AV & Penn AV Pittsburgh, PA 15208              Larimer
#
#       INCIDENTZONE  INCIDENTTRACT  COUNCIL_DISTRICT  PUBLIC_WORKS_DIVISION  \
# 53800            5         1303.0               9.0                    2.0
# 20988            6         2807.0               2.0                    5.0
# 23708            5         1115.0               NaN                    NaN
# 52643            5          802.0               7.0                    2.0
# 37414            6         1918.0               4.0                    5.0
# 53965            5         1306.0               NaN                    NaN
# 10748            3         1921.0               3.0                    5.0
# 38426            5         1115.0               NaN                    NaN
# 19970            5         1207.0               9.0                    2.0
# 41960            5         1208.0               9.0                    3.0
#
#                X          Y
# 53800 -79.899239  40.456067
# 20988 -80.067259  40.448924
# 23708        NaN        NaN
# 52643 -79.950360  40.462326
# 37414 -80.019073  40.393082
# 53965        NaN        NaN
# 10748 -79.999643  40.429627
# 38426        NaN        NaN
# 19970 -79.900142  40.460411
# 41960 -79.912427  40.454045

# %%
neighborhood_num = pittarrest["INCIDENTNEIGHBORHOOD"].nunique()
#get the arrest number in different neighborhoods
pittarrest["INCIDENTNEIGHBORHOOD"].value_counts()
# Out:
# Central Business District    3785
# South Side Flats             3186
# Carrick                      2199
# East Allegheny               2014
# Homewood South               1941
#                              ...
# Ridgemont                      35
# Central Northside              23
# Mt. Oliver Boro                18
# Troy Hill-Herrs Island          6
# Mt. Oliver Neighborhood         2
# Name: INCIDENTNEIGHBORHOOD, Length: 98, dtype: int64

# %% [markdown]
# In this case, we can get the number of arrests in Pittsrbugh's every neighborhoods.

# %%
arrests_num = pittarrest["INCIDENTNEIGHBORHOOD"].value_counts()
neighborhood_num = pittarrest["INCIDENTNEIGHBORHOOD"].nunique()
plt.title('Pittsburgh Police Arrest Data')
plt.ylabel('Arrests')
plt.xlabel('neighborhoods')
arrests_num.sort_values(ascending = False)[:neighborhood_num].plot.bar()

# %% [markdown]
# This is the bar chart which described the arrest data in all Pittsburgh neighborhoods. Then, we will choose the least five neighborhoods to get better visualization results. Neighborhood is more safety when less arrests were recorded.

# %%
arrests_num = pittarrest["INCIDENTNEIGHBORHOOD"].value_counts()
neighborhood_num = pittarrest["INCIDENTNEIGHBORHOOD"].nunique()
plt.title('Pittsburgh Police Arrest Data')
plt.ylabel('Arrests')
plt.xlabel('neighborhoods')
arrests_num.sort_values(ascending = True)[0:5].plot.bar()

# %% [markdown]
# # Summary
# In the bar char, we can conclude that Mt. Oliver Neighborhood has the least arrests, and Central Business District has most arrests, which means Mt. Oliver Neighborhood is relatively more safe than other neighborhoods. However, we should also consider about the population and police number in different neighborhood. We can not conclude Mt. Oliver Neighborhood is the best neighborhood in Pittsburgh only based on the number of arrests. We need to combine more factors to prove our results.
